# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyarrow as pa
import pyarrow.parquet as pq
import geopandas as gpd
import seaborn as sns

#Packages
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
from scipy import stats
pd.set_option('display.max_columns', None)

# %%
df = pd.read_parquet('C:/Users/Asus/Box/Flood Damage PredictionProject/Dataset/waterDepth_diff3.parquet.gzip')

# %%
df.shape[0]
# Out:
# 295745

# %%
df.head()
# Out:
#      agricultureStructureIndicator                  asOfDate  \
# 9                                0  2019-09-19T17:00:12.388Z
# 14                               0  2020-01-22T16:55:53.194Z
# 37                               0  2020-01-22T16:55:53.194Z
# 52                               0  2020-01-22T16:55:53.194Z
# 101                              0  2020-01-22T16:55:53.194Z
#
#      basementEnclosureCrawlspaceType  policyCount  crsClassificationCode  \
# 9                                NaN            1                    8.0
# 14                               NaN            1                    NaN
# 37                               NaN            1                    8.0
# 52                               NaN            1                    7.0
# 101                              NaN            1                    NaN
#
#                    dateOfLoss  elevatedBuildingIndicator  \
# 9   1995-03-11 00:00:00+00:00                          0
# 14  2005-08-29 00:00:00+00:00                          0
# 37  2005-08-29 00:00:00+00:00                          0
# 52  2004-09-16 00:00:00+00:00                          0
# 101 2005-08-29 00:00:00+00:00                          0
#
#     elevationCertificateIndicator  elevationDifference  baseFloodElevation  \
# 9                             nan                  NaN                 NaN
# 14                            nan                  1.0                11.0
# 37                            nan                  5.0                13.0
# 52                            nan                  NaN                 NaN
# 101                           nan                  NaN                 NaN
#
#     ratedFloodZone  houseWorship  locationOfContents  lowestAdjacentGrade  \
# 9               AE             0                 NaN                  NaN
# 14              AE             0                 NaN                  NaN
# 37              AE             0                 NaN                  NaN
# 52               X             0                 NaN                  NaN
# 101              X             0                 NaN                  NaN
#
#      lowestFloorElevation  numberOfFloorsInTheInsuredBuilding  \
# 9                     NaN                                 1.0
# 14                   12.0                                 4.0
# 37                   18.0                                 2.0
# 52                    NaN                                 2.0
# 101                   NaN                                 1.0
#
#      nonProfitIndicator  obstructionType  occupancyType  \
# 9                     0             10.0            1.0
# 14                    0              NaN            1.0
# 37                    0             10.0            1.0
# 52                    0             10.0            1.0
# 101                   0              NaN            1.0
#
#      originalConstructionDate            originalNBDate  \
# 9    1957-01-01T00:00:00.000Z  1993-11-29T00:00:00.000Z
# 14   1970-01-01T00:00:00.000Z  2003-06-20T00:00:00.000Z
# 37   1926-01-01T00:00:00.000Z  1997-06-16T00:00:00.000Z
# 52   1974-01-01T00:00:00.000Z  2000-02-15T00:00:00.000Z
# 101  1972-01-01T00:00:00.000Z  2001-06-27T00:00:00.000Z
#
#      amountPaidOnBuildingClaim  amountPaidOnContentsClaim  \
# 9                     12737.86                    6177.30
# 14                   169400.00                       0.00
# 37                   250000.00                  100000.00
# 52                   112634.48                   38301.23
# 101                   75000.00                   30000.00
#
#      amountPaidOnIncreasedCostOfComplianceClaim  \
# 9                                           0.0
# 14                                          0.0
# 37                                          0.0
# 52                                      10240.0
# 101                                         0.0
#
#      postFIRMConstructionIndicator rateMethod  smallBusinessIndicatorBuilding  \
# 9                                0          1                               0
# 14                               0          1                               0
# 37                               0          1                               0
# 52                               0          1                               0
# 101                              0          7                               0
#
#      totalBuildingInsuranceCoverage  totalContentsInsuranceCoverage  \
# 9                           72500.0                         35000.0
# 14                         169400.0                             0.0
# 37                         250000.0                        100000.0
# 52                         166000.0                         50000.0
# 101                         75000.0                         30000.0
#
#      yearOfLoss  primaryResidenceIndicator  buildingDamageAmount  \
# 9          1995                          1               16135.0
# 14         2005                          1              208743.0
# 37         2005                          1              323518.0
# 52         2004                          1              189617.0
# 101        2005                          1               75500.0
#
#     buildingDeductibleCode  netBuildingPaymentAmount  buildingPropertyValue  \
# 9                        9                  12737.86                72500.0
# 14                       5                 169400.00               218196.0
# 37                       0                 250000.00               329500.0
# 52                       3                 112634.48               200970.0
# 101                      0                  75000.00                75500.0
#
#     causeOfDamage condominiumCoverageTypeCode  contentsDamageAmount  \
# 9               1                           N                8055.0
# 14              1                           N                   NaN
# 37              1                           N              100500.0
# 52              4                           N               94049.0
# 101             1                           N               46829.0
#
#     contentsDeductibleCode  netContentsPaymentAmount  contentsPropertyValue  \
# 9                        9                   6177.30                    0.0
# 14                       0                      0.00                    NaN
# 37                       0                 100000.00                    0.0
# 52                       0                  38301.23                    0.0
# 101                      0                  30000.00                    0.0
#
#      disasterAssistanceCoverageRequired eventDesignationNumber  ficoNumber  \
# 9                                   0.0                   None       580.0
# 14                                  0.0                   None       653.0
# 37                                  0.0                   None       653.0
# 52                                  0.0                   None       643.0
# 101                                 0.0                   None       653.0
#
#      floodCharacteristicsIndicator  floodWaterDuration  floodproofedIndicator  \
# 9                              NaN                 0.0                      0
# 14                             NaN                 0.0                      0
# 37                             NaN                 0.0                      0
# 52                             NaN                 0.0                      0
# 101                            NaN                 0.0                      0
#
#             floodEvent  iccCoverage  netIccPaymentAmount  \
# 9             Flooding          NaN                  0.0
# 14   Hurricane Katrina      30000.0                  0.0
# 37   Hurricane Katrina      30000.0                  0.0
# 52      Hurricane Ivan      30000.0              10240.0
# 101  Hurricane Katrina      30000.0                  0.0
#
#      nfipRatedCommunityNumber nfipCommunityNumberCurrent    nfipCommunityName  \
# 9                     60195.0                       None    MONTEREY COUNTY *
# 14                   285256.0                       None      JACKSON COUNTY*
# 37                   285253.0                       None    GULFPORT, CITY OF
# 52                   120274.0                       None  SANTA ROSA COUNTY *
# 101                  285256.0                       None      JACKSON COUNTY*
#
#      nonPaymentReasonContents  nonPaymentReasonBuilding  numberOfUnits  \
# 9                         NaN                       NaN            1.0
# 14                        NaN                       NaN            1.0
# 37                        NaN                       NaN            1.0
# 52                        NaN                       NaN            1.0
# 101                       NaN                       NaN            1.0
#
#      buildingReplacementCost  contentsReplacementCost replacementCostBasis  \
# 9                        0.0                      0.0                    A
# 14                  220400.0                      NaN                    A
# 37                  330000.0                      0.0                    A
# 52                  203000.0                      0.0                    R
# 101                  78000.0                      0.0                    R
#
#      stateOwnedIndicator  waterDepth floodZoneCurrent  \
# 9                      0         0.0             None
# 14                     0         5.0             None
# 37                     0        10.0             None
# 52                     0         6.0             None
# 101                    0         2.0             None
#
#      buildingDescriptionCode  rentalPropertyIndicator state  \
# 9                        NaN                        0    CA
# 14                       NaN                        0    MS
# 37                       NaN                        0    MS
# 52                       NaN                        0    FL
# 101                      NaN                        0    MS
#
#               reportedCity  reportedZipCode  countyCode   censusTract  \
# 9    Currently Unavailable          93923.0      6053.0  6.053012e+09
# 14   Currently Unavailable          39564.0     28059.0  2.805904e+10
# 37   Currently Unavailable          39501.0     28047.0  2.804700e+10
# 52   Currently Unavailable          32563.0     12113.0  1.211301e+10
# 101  Currently Unavailable          39564.0     28059.0  2.805904e+10
#
#      censusBlockGroupFips  latitude  longitude  \
# 9            6.053012e+10      36.5     -121.9
# 14           2.805904e+11      30.4      -88.8
# 37           2.804700e+11      30.4      -89.1
# 52           1.211301e+11      30.4      -87.1
# 101          2.805904e+11      30.4      -88.7
#
#                                        id  relativeDamage dateOfLoss_bucket  \
# 9    f61464a9-46ad-4adb-9aed-4d175bb69569        0.222552        1995-03-05
# 14   3958c762-5b05-493f-9351-bb6079d2b9a7        0.956677        2005-08-28
# 37   15a48215-afe8-4365-8938-bff32f6a8774        0.981845        2005-08-28
# 52   ef067e3d-6d8a-494a-a184-f95e3eac8958        0.943509        2004-09-12
# 101  94dcc046-2ff8-4aa1-b371-e421ccd20a3b        1.000000        2005-08-28
#
#      median_waterDepth  mean_relativeDamage  diff_relativeDamage  \
# 9                 10.0             0.511228            -0.288676
# 14                10.0             0.789600             0.167077
# 37                18.0             0.887577             0.094268
# 52                 1.0             0.619809             0.323700
# 101                6.0             0.808837             0.191163
#
#      diff_waterDepth
# 9              -10.0
# 14              -5.0
# 37              -8.0
# 52               5.0
# 101             -4.0

# %%
df_check = df[df['median_waterDepth']==4]

# %%
df_check.shape[0]
# Out:
# 24888

# %%
df_check[df_check['waterDepth']==36].shape[0]
# Out:
# 497
